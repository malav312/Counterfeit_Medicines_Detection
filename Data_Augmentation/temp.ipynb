# %%
import spacy
import sqlite3
import pandas as pd
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from tqdm import tqdm
from joblib import Parallel, delayed
import os
from google.cloud import vision
import io
import string
from nltk.corpus import stopwords
from difflib import SequenceMatcher
from textblob import TextBlob
from fuzzywuzzy import process, fuzz
# Out:
# 2023-05-09 22:38:17.023050: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-09 22:38:17.728376: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-09 22:38:17.732983: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 22:38:25.600765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/malav312/Desktop/BTEP/Counterfeit_Medicines_Detection/venv/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
NUM_CORES = os.cpu_count()
NUM_CORES
# Out:
# 8

# %%
# read database vectors
nlp = spacy.load("en_core_web_sm")
conn = sqlite3.connect('removedwords.db')
c = conn.cursor()
c.execute("SELECT TEXT FROM text;")
db_names = [row[0].rstrip() for row in c.fetchall() if row[0].strip()]
db_names
# Out:
# ['augmentin 625 duo',
#  'azithral 500',
#  'allegra 120mg',
#  'avil 25',
#  'allegram',
#  'amoxyclav 625',
#  'azee 500',
#  'atarax 25mg',
#  'aciloc 150',
#  'arkamin',
#  'avomine',
#  'allegra 180mg',
#  'albendazole 400mg',
#  'alprax 025',
#  'altraday capsule sr',
#  'ativan 2mg',
#  'almox 500',
#  'atarax 10mg',
#  'aciloc rd 20',
#  'aldactone',
#  'amlokindat',
#  'axcer 90mg',
#  'ativan 1mg',
#  'aldigesic p 100mg325mg',
#  'alfoo 10mg tablet pr',
#  'alprax 05mg',
#  'anafortan 25 mg300 mg',
#  'ab phylline',
#  'althrocin 500',
#  'azicip 500',
#  'aldigesicsp',
#  'amoxycillin 500mg',
#  'acemiz plus',
#  'aceclo plus',
#  'alex cough lozenges lemon ginger',
#  'atorva',
#  'azmarda 50mg',
#  'amixideh',
#  'abflon',
#  'af kit',
#  'amlokind 5',
#  'amlong',
#  'amitone 10mg',
#  'aulin 100mg',
#  'ab phylline sr 200',
#  'azoran',
#  'amaryl 1mg',
#  'aztor 10',
#  'atorva 40',
#  'azax 500',
#  'anxit 05',
#  'anxit 025mg',
#  'acitrom 2',
#  'acemiz mr',
#  'akurit 4',
#  'acivir 400 dt',
#  'augmentin 1000 duo',
#  'acogut',
#  'amlip 5',
#  'aldactone 50',
#  'ampoxin 500',
#  'azee 250',
#  'alerid',
#  'augmentin 375',
#  'acenacp',
#  'abflo',
#  'ab phylline n',
#  'amifru 40',
#  'aciloc 300',
#  'ace proxyvon',
#  'admenta 5',
#  'aceclomr',
#  'aleridd',
#  'acemizs',
#  'allercetdc',
#  'aztolet 10',
#  'amaryl 2mg',
#  'amlopresat',
#  'ajaduo 25mg5mg',
#  'avanair 100',
#  'actonor tablet sr',
#  'aquazide 125',
#  'alaspan am',
#  'althrocin 250',
#  'azikem 500mg',
#  'aldosmin 500mg',
#  'amlovas 5',
#  'acitrom 1',
#  'af 150 tablet dt',
#  'amaryl m 1mg tablet pr',
#  'af 400',
#  'amantrel',
#  'atorva 20',
#  'acenacmr',
#  'asthalin 4',
#  'abiways',
#  'amaryl m 2mg tablet pr',
#  'azoran',
#  'ampilox',
#  'acogut 300 er',
#  'acuvin',
#  'abflo sr',
#  'airm',
#  'atorlipf',
#  'amlodac 5',
#  'aztor 40',
#  'alupent 10mg',
#  'amlip at',
#  'addnok 02mg',
#  'aldosmin 1000mg',
#  'antiflu 75mg',
#  'alerfix total tablet sr',
#  'aciclovir 400',
#  'atm 500',
#  'assurans',
#  'aten 50',
#  'azmarda 100mg',
#  'alzolam 05mg',
#  'ambulax',
#  'amlovasat',
#  'acivir 800 dt',
#  'alfusin tablet pr',
#  'aziwok 500',
#  'almoxcv 625',
#  'aceproxyvon cr',
#  'aprezo 30mg',
#  'amlosafe 3d',
#  'andial 2mg',
#  'acenext p 100mg325mg',
#  'asomex 25',
#  'alkof cofgel',
#  'azithral 250mg dt',
#  'alzolam 025mg',
#  'advent 625',
#  'alsita m 50mg500mg',
#  'axogurdsr',
#  'azoflox uti',
#  'azulix 2 mf tablet pr',
#  'amaryl mv 2mg tablet sr',
#  'azulix 1 mf tablet pr',
#  'aten 25',
#  'azibact 500',
#  'amlopres tl',
#  'actapro',
#  'aztor 20',
#  'atorfit cv 10',
#  'amtas 5',
#  'alrgee 120mg',
#  'avil 50mg',
#  'arip mt 5',
#  'alivher',
#  'altonil 3mg',
#  'allercet cold',
#  'atorlip 10',
#  'admenta 10',
#  'amox 500mg',
#  'azee 250',
#  'almox 250',
#  'aztor asp 75',
#  'arbiteltrio 50 tablet er',
#  'acivir 200 dt',
#  'aeromontb',
#  'amlopres 5',
#  'abevian',
#  'acamprol',
#  'atormac cv10',
#  'amnurite 10 tablet sr',
#  'amlonga',
#  'amoxyclav 375',
#  'abd 400mg',
#  'amlong 25',
#  'anacin',
#  'azithro 250mg',
#  'azimax 500',
#  'amlosafeat',
#  'air 180',
#  'adilip 135 tablet dr',
#  'amlosafe 5',
#  'amlogard 5mg',
#  'amaryl mv 1mg tablet sr',
#  'azee 500',
#  'alergin l',
#  'azr',
#  'angicambeta',
#  'amicobal 10mg1500mcg',
#  'actibile 300',
#  'amaryl m forte 2mg tablet pr',
#  'azicip 250',
#  'algesia cr 200mg20mg',
#  'atorva 80',
#  'acitrom 4',
#  'alsita 100mg',
#  'amnurite 5 mg1500 mcg',
#  'asomex 5',
#  'anaspas',
#  'addwize 10mg',
#  'amlong 10',
#  'abd plus',
#  'allercetm',
#  'atocor 10',
#  'augpen 625 bid',
#  'atcholf',
#  'alensold',
#  'arbiteltrio 25 tablet er',
#  'aceclo',
#  'amitone 25mg',
#  'acerad capsule sr',
#  'aculip h 125 mg5 mg',
#  'aztolet 20',
#  'amlopin 5',
#  'arimidex 1mg',
#  'alzilm 5',
#  'acuvert',
#  'alciflox 500mg',
#  'azax 250',
#  'aceclo spas',
#  'alphadol 025mcg',
#  'alex cough lozenges sugar free',
#  'arip mt 10',
#  'aricep 5',
#  'amlosafeat',
#  'aceclo sr',
#  'amitop 10',
#  'ambulax m',
#  'alcipro 500mg',
#  'assurans',
#  'augpen lb 625',
#  'aquaviron 40mg',
#  'anaflam th 4',
#  'alzil 5',
#  'amlo 5mg',
#  'amitone plus',
#  'akt 2',
#  'antacid',
#  'apresol',
#  'atchol 40',
#  'amlongh',
#  'arflur 3d',
#  'azmarda 200mg',
#  'amixide 10mg',
#  'avomine 25mg tablet md',
#  'arpizol 2mg',
#  'af 200',
#  'atorva asp 75',
#  'azivent 500',
#  'adtrol xt',
#  'acrotac 25mg',
#  'azathioprine 50mg',
#  'atchol 10',
#  'acutret 10',
#  'amitryn 10',
#  'amtasat',
#  'arpizol 10',
#  'aldactone 100',
#  'aztogold 20',
#  'addna',
#  'amtasm 50 tablet pr',
#  'akilosp',
#  'avas cv 10',
#  'acceclowocsp',
#  'amodep at',
#  'amlopres at 25',
#  'anxipan',
#  'abevia 100',
#  'alcoliv',
#  'amlovasm 550 tablet pr',
#  'amlosafe tm 40',
#  'aceflam p 100mg325mg',
#  'ascovent sr',
#  'amaryl 3mg',
#  'acotrust',
#  'amycloxlb',
#  'arbitelam',
#  'aprecap 12580',
#  'atorva f',
#  'amicline plus',
#  'acimol mr 100mg325mg250mg',
#  'abiways',
#  'asthakind',
#  'aprezo 10',
#  'air 120',
#  'amoxycillin 250mg',
#  'acenac sp 100mg325mg15mg',
#  'aginalat',
#  'allrite dc tablet er',
#  'asthalin 2',
#  'arip mt 2',
#  'alcet 5mg',
#  'aplazar',
#  'amicon 10',
#  'amaryl m forte 1mg tablet pr',
#  'amicline',
#  'ab2 kit',
#  'amitryn 10',
#  'afoglip m 500 tablet er',
#  'amlozaar',
#  'abel 40',
#  'acolate plus',
#  'ampilox ds',
#  'atorlip 20',
#  'altacef 500',
#  'amlokind 25',
#  'ambulaxet',
#  'acceclowocp',
#  'alprax forte 05 mg50 mg',
#  'alsitam 100 tablet er',
#  'axogurd nt tablet sr',
#  'anxiset 05',
#  'aldonil',
#  'anticold',
#  'alcros 100',
#  'atchol 20',
#  'azibest 500mg',
#  'amoxy 500mg',
#  'ascoril plus',
#  'azulix 2 mf forte tablet pr',
#  'amlokindh',
#  'amlopinm tablet pr',
#  'alevo 500',
#  'avanair 200',
#  'atorlip 40',
#  'anafortanmf 50mg250mg',
#  'amitriptyline hcl 25mg',
#  'amicet 5 mg60 mg',
#  'atm 250',
#  'akilossp',
#  'amlozaarh',
#  'aquazide 25',
#  'amlodac 25',
#  'amoxclav 500 mg125 mg',
#  'arvast 10',
#  'ata mont 20mg10mg',
#  'acimol 100 mg325 mg',
#  'antidep 25mg',
#  'almox 250 mg tablet dt',
#  'azicip 250',
#  'ampoxin 250',
#  'avanext 100mg',
#  'aztor 80',
#  'akair lc',
#  'azulix 1',
#  'asprito 2',
#  'asomexat',
#  'amlovas 25',
#  'amlovas h',
#  'amodep 5',
#  'acidose 500mg',
#  'actapro',
#  'avas 20',
#  'arflurp',
#  'asiclopam',
#  'atorlip gold 20',
#  'amantex',
#  'acenac',
#  'almefkem spas 10mg250mg',
#  'amcard 5',
#  'avene abbott 05mg10mg',
#  'atcholasp',
#  'arbitelh',
#  'axcer 60mg',
#  'abiwaysm tablet sr',
#  'amlopres l',
#  'amifru plus',
#  'armotraz',
#  'aldigesic th 100mg4mg',
#  'abixim 200mg',
#  'arbitelmt 50 tablet er',
#  'azikem 250mg',
#  'atend',
#  'altonil 5 tablet md',
#  'azipro 500',
#  'alsita 50mg',
#  'amlip 10',
#  'acimol forte 100mg325mg15mg',
#  'atocor 40',
#  'angicam 5mg',
#  'aprezo 20',
#  'actibile 150',
#  'atorva gold 20',
#  'alzero m',
#  'azulix 1 mf forte tablet pr',
#  'azimax 250',
#  'aloja 25',
#  'arbitelct 40',
#  'anthocyntx',
#  'actoid 25mg',
#  'atocor 10',
#  'azulix 2',
#  'aztor 5',
#  'aziwok 250',
#  'acitrin 25mg',
#  'antiblue 10mg',
#  'arpimune me 50mg',
#  'azithral',
#  'ampiclox 250mg250mg',
#  'analiv 500',
#  'actifed 25 mg25 mg',
#  'amlong a25',
#  'azibact 250',
#  'alendrate 70mg',
#  'ambrican 5',
#  'arkamin h',
#  'atorfit 10',
#  'angizem cd 90 capsule er',
#  'azovas 16mg',
#  'advent 457mg tablet dt',
#  'alcros 200',
#  'amixide',
#  'aztogold 10',
#  'alcoban 500mg',
#  'arvasta 75',
#  'amlopinat',
#  'azilab 500mg',
#  'amnuring 10 tablet sr',
#  'ablung 200mg tablet sr',
#  'azusa 16',
#  'afoglip',
#  'acefen sp',
#  'aceclopar 100mg325mg',
#  'acotrust od 300mg tablet er',
#  'avas 40',
#  'acegaba nt 400mg10mg',
#  'alerid cold',
#  'acolate',
#  'antoxid e softgel',
#  'agoprex',
#  'amlip 25',
#  'af 300',
#  'abiways 200 sr',
#  'atorva 5',
#  'ambizyme 300mg',
#  'acegrow 3d',
#  'alerfri',
#  'aceret 25',
#  'alprax plus tablet sr',
#  'amtasm 25 tablet pr',
#  'anset 4mg tablet md',
#  'acecloren',
#  'atraxin 25',
#  'atorva gold 10',
#  'amlongtl 40',
#  'apraize 30',
#  'aspirin 300mg',
#  'akurit',
#  'agna 10000 capsule dr',
#  'atormac gold 10',
#  'altonil plus 5',
#  'acimolsp',
#  'avas cv 20',
#  'amlopres 25',
#  'aceclowal p 100mg500mg',
#  'ablung 100mg',
#  'armod 50',
#  'alcros sb 50',
#  'alkem cold 5 mg500 mg5 mg',
#  'azovas t 40',
#  'asomextm',
#  'acekay sera',
#  'alprax 1mg tablet sr',
#  'amoxiblecl 625',
#  'alzilm 10',
#  'ageless',
#  'agycin 500mg',
#  'amnurite beta 1040 er',
#  'altonil 10',
#  'atorlip gold 10',
#  'aceloflam plus',
#  'altonil plus 10',
#  'ampilox cv 500 mg125 mg',
#  'alconol 500mg',
#  'atchol cv',
#  'atormac gold 20',
#  'allegra 120mg',
#  'acepar 100mg325mg',
#  'ampanel 4',
#  'aztor ez',
#  'alfakit',
#  'atocor 20',
#  'amitryn 25',
#  'atormac cv 20',
#  'arbitelmt 25 tablet er',
#  'azi 500mg',
#  'alphadopa',
#  'abz 400mg',
#  'allerkast lc',
#  'amlodac t 40 mg5 mg',
#  'absolut dm',
#  'azikind 500mg',
#  'avoprost d 8mg05mg',
#  'arbitelav',
#  'atorlip 80',
#  'atocorcv 10',
#  'amnuring 5 tablet sr',
#  'aldactone t 10',
#  'addkay tablet pr',
#  'acotibien 100mg',
#  'alsitam 100 forte tablet er',
#  'amoxil 250mg',
#  'amicet plus',
#  'azitus 500',
#  'atorlipasp 20',
#  'allegra 30mg',
#  'acutrol c 400',
#  'ace proxyvon th 4',
#  'almefkemd',
#  'ata',
#  'amisant 200',
#  'allercetl',
#  'arbitel 20',
#  'acrotac 10mg',
#  'aginal 5',
#  'amtas 25',
#  'aricep 10',
#  'astin cv 10',
#  'amodep 5',
#  'arifine 25',
#  'azithral 250mg dt',
#  'aricepm',
#  'amoxy 250mg',
#  'alorti',
#  'atormac tg',
#  'azovas 8mg',
#  'afoglip m 1000 tablet er',
#  'anxipam 05mg tablet md',
#  'abmac',
#  'anin',
#  'apresol plus',
#  'azulix mv 2mg500mg03mg tablet sr',
#  'aceproxyvon sp',
#  'angistat 25 capsule tr',
#  'anafortan n 100 mg50 mg',
#  'atorlip cv',
#  'amoxil 250mg tablet dt',
#  'acemiz 100mg',
#  'alrista plus tablet sr',
#  'ascapil 12a tablet dt',
#  'aisa',
#  'acolate p plus',
#  'anleodsr',
#  'amlopres 10',
#  'ampoxincv 500mg125mg',
#  'azilide 250',
#  'apraize 10',
#  'atorecasp',
#  'amitrync',
#  'azee 1000',
#  'adefresh 400',
#  'abphylin 100mg',
#  'azulix mv 202 tablet sr',
#  'absolut dm',
#  'ambrodilxp',
#  'augxetil 500mg',
#  'actiheald',
#  'adilip 45 tablet dr',
#  'alfa gpc',
#  'andriol 40mg testocap',
#  'analgin 500mg',
#  'asprito 5',
#  'atrest 25',
#  'amlodac m tablet pr',
#  'atocor gold 20',
#  'atocor 80',
#  'actifed plus',
#  'alcinac p 100mg325mg',
#  'arpizol 15',
#  'arigaba nt',
#  'amlomed at 5mg50mg',
#  'azusa t 840',
#  'azomycin 500',
#  'abortab 200mg',
#  'attentrol 10mg',
#  'amace',
#  'aim7 60 xr',
#  'atchol gold 10',
#  'acenacp',
#  'aldonil plus tablet sr',
#  'acotrust',
#  'aldep 10',
#  'at sp',
#  'anxol',
#  'addwize od 18mg',
#  'amipride 50',
#  'altiva 120mg',
#  'aclonsp',
#  'allenza',
#  'atrovas 40mg',
#  'amtas 10',
#  'amlokind beta 5mg25mg tablet pr',
#  'afogatran 110',
#  'auradex 4mg',
#  'acetamide 250mg',
#  'agmacet 10mg',
#  'amloz at',
#  'arip mt 10',
#  'alivher es',
#  'ace plus',
#  'alides 5mg',
#  'alastin am',
#  'amclaid 625',
#  'avoprost 8mg',
#  'amiline 10mg',
#  'arvast f 10',
#  'amloz 5',
#  'azulix 4 mf forte tablet pr',
#  'amtasat 25',
#  'arophyll hd 10mg120mg200mg',
#  'acitrom 05',
#  'asar 40',
#  'anxit 05 sr',
#  'afoglip m 500 tablet er',
#  'arvastcf 10 capsule dr',
#  'augmentin 375 duo',
#  'axinervep tablet sr',
#  'adiflam plus 400 mg500 mg',
#  'amitop m 5mg1500mcg',
#  'asomexd',
#  'azro 500',
#  'answell 400 mg325 mg',
#  'acenext 100mg',
#  'azilup 500 mg',
#  'aceron tc',
#  'aldigesicrab capsule sr',
#  'action or 1000mg',
#  'adilin 40mg tablet sr',
#  'alfalog',
#  'azax 500',
#  'amlovasl',
#  'atorsave d 10',
#  'amit 10 mg',
#  'azivent 250',
#  'azapure',
#  'akmeentoquol',
#  'atherochek 10',
#  'axepta 18mg',
#  'alconil 500mg',
#  'actonor plus',
#  'accardi mr tablet mr',
#  'acenacsr',
#  'albutamol plus',
#  'azirin 500mg',
#  'azusa 8mg',
#  'amlodac ch',
#  'atorec 10',
#  'atrest 125',
#  'abvida 50mg',
#  'asa 75mg',
#  'amnurite 25 tablet sr',
#  'atorlip 5',
#  'amlovasm 525 tablet pr',
#  'aziford 500mg',
#  'anglit 26 tablet cr',
#  'amlogard 25mg',
#  'amdepin 5',
#  'abresp',
#  'amiodar 200',
#  'amazeo od 100 tablet sr',
#  'acocontin tablet cr',
#  'alphacept 8',
#  'augxetil cv 500',
#  'asoltat',
#  'acocare 300mg tablet sr',
#  'anti cold',
#  'advastat 10',
#  'aldigesic mr',
#  'arzu 10',
#  'asprito 10',
#  'azifast 250',
#  'alenix 5',
#  'atorbest 10',
#  'amide 25',
#  'aleva 5mg',
#  'amlopin 25',
#  'aceth 4',
#  'arip mt 15',
#  'alerfix',
#  'admol 650mg',
#  'arip 5mg',
#  'aceclomaxsp',
#  'avapar',
#  'atorsave cv 10',
#  'anaflam xps',
#  'ab day 100mg',
#  'amitril 10mg',
#  'azintas 500mg',
#  'amt 25mg',
#  'aculip 25 mg10 mg',
#  'aplev m 5mg10mg',
#  'actoid 10',
#  'aphyrenn',
#  'apigy 25',
#  'amaryl 4mg',
#  'amitop m 5',
#  'atorfit cv 40',
#  'atrovas 10mg',
#  'altoran 40',
#  'alpalide 100mg',
#  'amlogard 10mg',
#  'ambrolite 30',
#  'axepta 25mg',
#  'apraize 20',
#  'acesp',
#  'amlosafe 25',
#  'acenext sp 100 mg500 mg15 mg',
#  'amitrip 10mg',
#  'anxozap 15',
#  'atchol gold 20',
#  'acutret 5',
#  'acemyoset p',
#  'amlo at 5 mg50 mg',
#  'amirid',
#  'acendolr capsule sr',
#  'alkepin odt 125mg',
#  'amazeo 50',
#  'amucoe nac',
#  'af 50 tablet dt',
#  'abixim o',
#  'aceclodol p 100mg500mg',
#  'amlosafe h',
#  'avacardat',
#  'aldo 5mg',
#  'aztric 40',
#  'atorva e 40',
#  'atazis 10mg',
#  'amlopinm 5mg25mg',
#  'ace revelol 505 tablet er',
#  'arvast 20',
#  'aciban 40',
#  'alsitam 50 forte tablet er',
#  'amlovasat 25',
#  'alkepin odt 25mg',
#  'altam 25mg',
#  'adilan 40mg tablet sr',
#  'acepar sp 100mg325mg15mg',
#  'asomexlt',
#  'amitryn 25',
#  'arorab hd 30mg40mg capsule sr',
#  'atorsave 40',
#  'aceclomaxp',
#  'anzilum 025 mg',
#  'amodeptmh',
#  'aziwin 500',
#  'acedol p 100 mg500 mg',
#  'amchek 5',
#  'arigaba nt 100',
#  'asert d tablet er',
#  'aclopar sp 100mg325mg10mg',
#  'acecare sp',
#  'ampiloxlb',
#  'arbitelamh',
#  'amlosafe mt 25 tablet pr',
#  'arvast 5',
#  'alizap 30mg',
#  'assault novo 200 mg500 mg',
#  'avas 80',
#  'aretha',
#  'amigaba ls',
#  'astharid t',
#  'azibest 250mg',
#  'alzil 10',
#  'angicam lt 50 mg5 mg',
#  'alergin 10mg',
#  'azileb 500mg',
#  'antidep 75',
#  'alzil m forte',
#  'alergin cold total',
#  'alerfri sf 650 mg60 mg25 mg',
#  'acp tablet mr',
#  'atorva e 10mg10mg',
#  'abvidam 50mg500mg eazy glide',
#  'apexitra sb 130',
#  'aclopar 100mg500mg',
#  'ambulaxfm',
#  'alkof q',
#  'aceral capsule sr',
#  'alcecost sp 100mg325mg10mg',
#  'acera 20',
#  'amclawyn 500mg125mg',
#  'amlo 10mg',
#  'amchekat',
#  'agra 100mg',
#  'amlosafe 3d 80',
#  'aciban 20',
#  'acerest plus',
#  'acelopara',
#  'acimol 200mg tablet sr',
#  'acenext mr 100mg325mg250mg',
#  'aceloflam mr',
#  'amazeo 100',
#  'amitone forte 25 mg10 mg',
#  'apixator 25',
#  'angizem cd 120 capsule er',
#  'abvida 100mg tablet sr',
#  'auxisodaec 500',
#  'aldostix 20 mg50 mg',
#  'amlor 5mg',
#  'azrolid 500mg',
#  'alinol 10',
#  'amnurite p 10mg75mg',
#  'azulix 3 mf forte tablet pr',
#  'arkapres 100',
#  'azee 200 dt',
#  'azulix 05 mf tablet pr',
#  'amiwel 10',
#  'avas gold 75mg20mg75mg',
#  'apixator 5',
#  'acibro plus tablet sr',
#  'actinin o 20mg soft gelatin',
#  'alcinac mr',
#  'azy 500mg',
#  'aciloc d 10 mg150 mg',
#  'axinervenp',
#  'amicon 25mg',
#  'angizaarh',
#  'asthalin 2',
#  'amclox',
#  'allerzine l 5mg',
#  'alsartanh',
#  'angicamm tablet pr',
#  'atocorcv 20',
#  'abvidam 50500 eazy glide tablet sr',
#  'acipsor 25mg',
#  'avanext 200',
#  'asunra 400mg',
#  'acefile sp 100mg325mg10mg',
#  'allerblis m 20mg10mg',
#  'agmamol 500mg',
#  'averzine 10',
#  'azerva 40',
#  'atorfit cv gold 20',
#  'aps',
#  'azitro 500mg',
#  'act nvp',
#  'atrovas 20mg',
#  'apxenta 30mg',
#  'almotan 625',
#  'armod 150',
#  'atrolet 10',
#  'algest sr 200',
#  'averzine 25mg',
#  'amlosafels 55',
#  'amloz at 25',
#  'acetyl salicylic acid 50mg',
#  'astharid plus',
#  'angizaar 50',
#  'anxiset plus 05 mg10 mg',
#  'algin 100 mg500 mg',
#  'auxen d 500mg10mg',
#  'adoxy lb',
#  'aldigesic 100mg500mg250mg tablet mr',
#  'androsure 40mg',
#  'artamin 250mg',
#  'amigold 50',
#  'amazeo od 200 tablet sr',
#  'azipro 250',
#  'acecareplus',
#  'atormac 20',
#  'aspisol 150',
#  'atorsave f',
#  'arflurmr',
#  'actv 24',
#  'advastat cv 10',
#  'amigold 100',
#  'aricepm forte',
#  'apriglimmv 303 tablet sr',
#  'amtase',
#  'alphadol 05mcg soft gelatin',
#  'arreno capsule er',
#  'anafranil 25mg',
#  'apriglimmv 2 tablet sr',
#  'asomextm 5',
#  'amlosafe tm 80',
#  'alkepin odt 100mg',
#  'atorfit 20',
#  'arigaba 100',
#  'acetal mr 100mg325mg250mg',
#  'atz 50',
#  'attentrol 18',
#  'abrozac 100mg600mg',
#  'anadom 10mg500mg',
#  'asthavent 25mg respules',
#  'adova',
#  'allrite',
#  'alakast fa 10mg120mg200mg',
#  'azuvas 20gold',
#  'azitreat 500mg',
#  'azuvas 10',
#  'adineplus',
#  'adoc sp 100mg325mg',
#  'atorin 10',
#  'augulab 500mg125mg',
#  'amaryl mp 2mg tablet sr',
#  'alenix 10mg',
#  'amlace',
#  'anaflam xp 100mg325mg',
#  'azento 500mg',
#  'arifine 5mg',
#  'attera 10mg',
#  'aldactone f',
#  'aziagma 500mg',
#  'acemiz 200 sr',
#  'abmont 3d 10mg120mg200mg',
#  'altaxo 200 tablet dt',
#  'acetonp',
#  'alleronem',
#  'arflur cr',
#  'azeldip 16',
#  'alfugressd tablet sr',
#  'azimac 500mg',
#  'aldigesic spas 80mg100mg',
#  'azicip 500',
#  'anneal 60mg800mg5mg',
#  'asozen sr plus 100mg325mg10mg',
#  'amlozaar',
#  'arostat 10mg',
#  'allerduo 20mg10mg',
#  'asarct 40125',
#  'amantrel',
#  'almox dt 125',
#  'atorecf',
#  'alcinac forte 100mg325mg15mg',
#  'alkof cough lozenges orange',
#  'azuma 500mg',
#  'avort kit',
#  'azuvasf 20',
#  'apigy 5',
#  'amlovasm 2525 tablet pr',
#  'akilos tablet mr',
#  'alert 120mg',
#  'almont lc 5mg10mg',
#  'altonil plus 3',
#  'amaryl mp 2mg tablet er',
#  'abendol plus 12mg400mg',
#  'alrista forte',
#  'azulix mv 1mg500mg02mg tablet sr',
#  'alprasafe 025mg',
#  'aplex 30mg',
#  'alkepin odt 50mg',
#  'aldactone t 5',
#  'adnurve sr',
#  'alerabdsr',
#  'altacef 250mg',
#  'acepar mr',
#  'algina 650',
#  'ace',
#  'akme ct 10',
#  'alphaceptd 8',
#  'amcard 25',
#  'amox 250mg',
#  'azro 500',
#  'altrizm',
#  'apale',
#  'actiful 25mg',
#  'acefile p 100mg325mg',
#  'amlibon 5mg',
#  'afoglip',
#  'arpizol 20',
#  'acutret 30',
#  'amlovas ls',
#  'atorsave 80',
#  'arip mt 20',
#  'anafast 100mg325mg',
#  'actin',
#  'allerfree',
#  'amnurite beta 520 er',
#  'aceks',
#  'algesia p 100 mg500 mg',
#  'acenomac 2',
#  'anort 30',
#  'antrumdsr capsule capsule sr',
#  'ace p tablet 100 mg325 mg',
#  'asa 50mg',
#  'actiheal',
#  'acifix 20mg',
#  'arvast gold 10mg',
#  'atecard d',
#  'arden 500mg',
#  'acendolp',
#  'alphacept 8',
#  'amlong mt 525 tablet pr',
#  'acer plus',
#  'atocor 5',
#  'aziford 250mg',
#  'alflox 400',
#  'apexitra 200',
#  'aloja 125',
#  'avva 250mg',
#  'arthocering',
#  'arorabdsr',
#  'aceloflam xp 100 mg325 mg',
#  'angised 05mg',
#  'anaflam 400mg325mg',
#  'azithral kidtab',
#  'antegy m 20mg10mg',
#  'amisant 50',
#  'acnex 20',
#  'amlosafe 25',
#  'azuvas 40',
#  'amlokind tm 40mg5mg',
#  'argifizz 1500mg',
#  'azi 250mg',
#  ...]

# %%
def generate_vecs(name):
    return nlp(name).vector

# %%
delayed_func = [delayed(generate_vecs)(name) for name in db_names]
parallel_pool = Parallel(n_jobs=NUM_CORES//2, backend = 'multiprocessing', verbose = 10)
db_vecs = parallel_pool(delayed_func)
db_vecs = np.array(db_vecs)
# Out:
# [Parallel(n_jobs=4)]: Using backend MultiprocessingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0536s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0818s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1832s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 288 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 480 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=4)]: Done 584 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 704 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 824 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=4)]: Done 960 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=4)]: Done 1096 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=4)]: Done 1248 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=4)]: Done 1568 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=4)]: Done 1736 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=4)]: Done 1920 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=4)]: Done 2104 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=4)]: Done 2304 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=4)]: Done 2504 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=4)]: Done 2720 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=4)]: Done 2936 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=4)]: Done 3168 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=4)]: Done 3400 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=4)]: Done 3648 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=4)]: Done 3896 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=4)]: Done 4160 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=4)]: Done 4424 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=4)]: Done 4704 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=4)]: Done 4984 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=4)]: Done 5280 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=4)]: Done 5576 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=4)]: Done 5888 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=4)]: Done 6200 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=4)]: Done 6528 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 6856 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 7200 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 7544 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 7904 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 8264 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 8640 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 9016 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 9408 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 9800 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 10208 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 10616 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 11040 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 11464 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 11904 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done 12344 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=4)]: Done 12800 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=4)]: Done 13256 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=4)]: Done 13728 tasks      | elapsed:  2.1min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 delayed_func = [delayed(generate_vecs)(name) for name in db_names]
#       2 parallel_pool = Parallel(n_jobs=NUM_CORES//2, backend = 'multiprocessing', verbose = 10)
# ----> 3 db_vecs = parallel_pool(delayed_func)
#       4 db_vecs = np.array(db_vecs)
#
# File ~/Desktop/BTEP/Counterfeit_Medicines_Detection/venv/lib/python3.8/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/Desktop/BTEP/Counterfeit_Medicines_Detection/venv/lib/python3.8/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File /usr/lib/python3.8/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /usr/lib/python3.8/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /usr/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
db_names
# Out:
# ['augmentin 625 duo',
#  'azithral 500',
#  'allegra 120mg',
#  'avil 25',
#  'allegram',
#  'amoxyclav 625',
#  'azee 500',
#  'atarax 25mg',
#  'aciloc 150',
#  'arkamin',
#  'avomine',
#  'allegra 180mg',
#  'albendazole 400mg',
#  'alprax 025',
#  'altraday capsule sr',
#  'ativan 2mg',
#  'almox 500',
#  'atarax 10mg',
#  'aciloc rd 20',
#  'aldactone',
#  'amlokindat',
#  'axcer 90mg',
#  'ativan 1mg',
#  'aldigesic p 100mg325mg',
#  'alfoo 10mg tablet pr',
#  'alprax 05mg',
#  'anafortan 25 mg300 mg',
#  'ab phylline',
#  'althrocin 500',
#  'azicip 500',
#  'aldigesicsp',
#  'amoxycillin 500mg',
#  'acemiz plus',
#  'aceclo plus',
#  'alex cough lozenges lemon ginger',
#  'atorva',
#  'azmarda 50mg',
#  'amixideh',
#  'abflon',
#  'af kit',
#  'amlokind 5',
#  'amlong',
#  'amitone 10mg',
#  'aulin 100mg',
#  'ab phylline sr 200',
#  'azoran',
#  'amaryl 1mg',
#  'aztor 10',
#  'atorva 40',
#  'azax 500',
#  'anxit 05',
#  'anxit 025mg',
#  'acitrom 2',
#  'acemiz mr',
#  'akurit 4',
#  'acivir 400 dt',
#  'augmentin 1000 duo',
#  'acogut',
#  'amlip 5',
#  'aldactone 50',
#  'ampoxin 500',
#  'azee 250',
#  'alerid',
#  'augmentin 375',
#  'acenacp',
#  'abflo',
#  'ab phylline n',
#  'amifru 40',
#  'aciloc 300',
#  'ace proxyvon',
#  'admenta 5',
#  'aceclomr',
#  'aleridd',
#  'acemizs',
#  'allercetdc',
#  'aztolet 10',
#  'amaryl 2mg',
#  'amlopresat',
#  'ajaduo 25mg5mg',
#  'avanair 100',
#  'actonor tablet sr',
#  'aquazide 125',
#  'alaspan am',
#  'althrocin 250',
#  'azikem 500mg',
#  'aldosmin 500mg',
#  'amlovas 5',
#  'acitrom 1',
#  'af 150 tablet dt',
#  'amaryl m 1mg tablet pr',
#  'af 400',
#  'amantrel',
#  'atorva 20',
#  'acenacmr',
#  'asthalin 4',
#  'abiways',
#  'amaryl m 2mg tablet pr',
#  'azoran',
#  'ampilox',
#  'acogut 300 er',
#  'acuvin',
#  'abflo sr',
#  'airm',
#  'atorlipf',
#  'amlodac 5',
#  'aztor 40',
#  'alupent 10mg',
#  'amlip at',
#  'addnok 02mg',
#  'aldosmin 1000mg',
#  'antiflu 75mg',
#  'alerfix total tablet sr',
#  'aciclovir 400',
#  'atm 500',
#  'assurans',
#  'aten 50',
#  'azmarda 100mg',
#  'alzolam 05mg',
#  'ambulax',
#  'amlovasat',
#  'acivir 800 dt',
#  'alfusin tablet pr',
#  'aziwok 500',
#  'almoxcv 625',
#  'aceproxyvon cr',
#  'aprezo 30mg',
#  'amlosafe 3d',
#  'andial 2mg',
#  'acenext p 100mg325mg',
#  'asomex 25',
#  'alkof cofgel',
#  'azithral 250mg dt',
#  'alzolam 025mg',
#  'advent 625',
#  'alsita m 50mg500mg',
#  'axogurdsr',
#  'azoflox uti',
#  'azulix 2 mf tablet pr',
#  'amaryl mv 2mg tablet sr',
#  'azulix 1 mf tablet pr',
#  'aten 25',
#  'azibact 500',
#  'amlopres tl',
#  'actapro',
#  'aztor 20',
#  'atorfit cv 10',
#  'amtas 5',
#  'alrgee 120mg',
#  'avil 50mg',
#  'arip mt 5',
#  'alivher',
#  'altonil 3mg',
#  'allercet cold',
#  'atorlip 10',
#  'admenta 10',
#  'amox 500mg',
#  'azee 250',
#  'almox 250',
#  'aztor asp 75',
#  'arbiteltrio 50 tablet er',
#  'acivir 200 dt',
#  'aeromontb',
#  'amlopres 5',
#  'abevian',
#  'acamprol',
#  'atormac cv10',
#  'amnurite 10 tablet sr',
#  'amlonga',
#  'amoxyclav 375',
#  'abd 400mg',
#  'amlong 25',
#  'anacin',
#  'azithro 250mg',
#  'azimax 500',
#  'amlosafeat',
#  'air 180',
#  'adilip 135 tablet dr',
#  'amlosafe 5',
#  'amlogard 5mg',
#  'amaryl mv 1mg tablet sr',
#  'azee 500',
#  'alergin l',
#  'azr',
#  'angicambeta',
#  'amicobal 10mg1500mcg',
#  'actibile 300',
#  'amaryl m forte 2mg tablet pr',
#  'azicip 250',
#  'algesia cr 200mg20mg',
#  'atorva 80',
#  'acitrom 4',
#  'alsita 100mg',
#  'amnurite 5 mg1500 mcg',
#  'asomex 5',
#  'anaspas',
#  'addwize 10mg',
#  'amlong 10',
#  'abd plus',
#  'allercetm',
#  'atocor 10',
#  'augpen 625 bid',
#  'atcholf',
#  'alensold',
#  'arbiteltrio 25 tablet er',
#  'aceclo',
#  'amitone 25mg',
#  'acerad capsule sr',
#  'aculip h 125 mg5 mg',
#  'aztolet 20',
#  'amlopin 5',
#  'arimidex 1mg',
#  'alzilm 5',
#  'acuvert',
#  'alciflox 500mg',
#  'azax 250',
#  'aceclo spas',
#  'alphadol 025mcg',
#  'alex cough lozenges sugar free',
#  'arip mt 10',
#  'aricep 5',
#  'amlosafeat',
#  'aceclo sr',
#  'amitop 10',
#  'ambulax m',
#  'alcipro 500mg',
#  'assurans',
#  'augpen lb 625',
#  'aquaviron 40mg',
#  'anaflam th 4',
#  'alzil 5',
#  'amlo 5mg',
#  'amitone plus',
#  'akt 2',
#  'antacid',
#  'apresol',
#  'atchol 40',
#  'amlongh',
#  'arflur 3d',
#  'azmarda 200mg',
#  'amixide 10mg',
#  'avomine 25mg tablet md',
#  'arpizol 2mg',
#  'af 200',
#  'atorva asp 75',
#  'azivent 500',
#  'adtrol xt',
#  'acrotac 25mg',
#  'azathioprine 50mg',
#  'atchol 10',
#  'acutret 10',
#  'amitryn 10',
#  'amtasat',
#  'arpizol 10',
#  'aldactone 100',
#  'aztogold 20',
#  'addna',
#  'amtasm 50 tablet pr',
#  'akilosp',
#  'avas cv 10',
#  'acceclowocsp',
#  'amodep at',
#  'amlopres at 25',
#  'anxipan',
#  'abevia 100',
#  'alcoliv',
#  'amlovasm 550 tablet pr',
#  'amlosafe tm 40',
#  'aceflam p 100mg325mg',
#  'ascovent sr',
#  'amaryl 3mg',
#  'acotrust',
#  'amycloxlb',
#  'arbitelam',
#  'aprecap 12580',
#  'atorva f',
#  'amicline plus',
#  'acimol mr 100mg325mg250mg',
#  'abiways',
#  'asthakind',
#  'aprezo 10',
#  'air 120',
#  'amoxycillin 250mg',
#  'acenac sp 100mg325mg15mg',
#  'aginalat',
#  'allrite dc tablet er',
#  'asthalin 2',
#  'arip mt 2',
#  'alcet 5mg',
#  'aplazar',
#  'amicon 10',
#  'amaryl m forte 1mg tablet pr',
#  'amicline',
#  'ab2 kit',
#  'amitryn 10',
#  'afoglip m 500 tablet er',
#  'amlozaar',
#  'abel 40',
#  'acolate plus',
#  'ampilox ds',
#  'atorlip 20',
#  'altacef 500',
#  'amlokind 25',
#  'ambulaxet',
#  'acceclowocp',
#  'alprax forte 05 mg50 mg',
#  'alsitam 100 tablet er',
#  'axogurd nt tablet sr',
#  'anxiset 05',
#  'aldonil',
#  'anticold',
#  'alcros 100',
#  'atchol 20',
#  'azibest 500mg',
#  'amoxy 500mg',
#  'ascoril plus',
#  'azulix 2 mf forte tablet pr',
#  'amlokindh',
#  'amlopinm tablet pr',
#  'alevo 500',
#  'avanair 200',
#  'atorlip 40',
#  'anafortanmf 50mg250mg',
#  'amitriptyline hcl 25mg',
#  'amicet 5 mg60 mg',
#  'atm 250',
#  'akilossp',
#  'amlozaarh',
#  'aquazide 25',
#  'amlodac 25',
#  'amoxclav 500 mg125 mg',
#  'arvast 10',
#  'ata mont 20mg10mg',
#  'acimol 100 mg325 mg',
#  'antidep 25mg',
#  'almox 250 mg tablet dt',
#  'azicip 250',
#  'ampoxin 250',
#  'avanext 100mg',
#  'aztor 80',
#  'akair lc',
#  'azulix 1',
#  'asprito 2',
#  'asomexat',
#  'amlovas 25',
#  'amlovas h',
#  'amodep 5',
#  'acidose 500mg',
#  'actapro',
#  'avas 20',
#  'arflurp',
#  'asiclopam',
#  'atorlip gold 20',
#  'amantex',
#  'acenac',
#  'almefkem spas 10mg250mg',
#  'amcard 5',
#  'avene abbott 05mg10mg',
#  'atcholasp',
#  'arbitelh',
#  'axcer 60mg',
#  'abiwaysm tablet sr',
#  'amlopres l',
#  'amifru plus',
#  'armotraz',
#  'aldigesic th 100mg4mg',
#  'abixim 200mg',
#  'arbitelmt 50 tablet er',
#  'azikem 250mg',
#  'atend',
#  'altonil 5 tablet md',
#  'azipro 500',
#  'alsita 50mg',
#  'amlip 10',
#  'acimol forte 100mg325mg15mg',
#  'atocor 40',
#  'angicam 5mg',
#  'aprezo 20',
#  'actibile 150',
#  'atorva gold 20',
#  'alzero m',
#  'azulix 1 mf forte tablet pr',
#  'azimax 250',
#  'aloja 25',
#  'arbitelct 40',
#  'anthocyntx',
#  'actoid 25mg',
#  'atocor 10',
#  'azulix 2',
#  'aztor 5',
#  'aziwok 250',
#  'acitrin 25mg',
#  'antiblue 10mg',
#  'arpimune me 50mg',
#  'azithral',
#  'ampiclox 250mg250mg',
#  'analiv 500',
#  'actifed 25 mg25 mg',
#  'amlong a25',
#  'azibact 250',
#  'alendrate 70mg',
#  'ambrican 5',
#  'arkamin h',
#  'atorfit 10',
#  'angizem cd 90 capsule er',
#  'azovas 16mg',
#  'advent 457mg tablet dt',
#  'alcros 200',
#  'amixide',
#  'aztogold 10',
#  'alcoban 500mg',
#  'arvasta 75',
#  'amlopinat',
#  'azilab 500mg',
#  'amnuring 10 tablet sr',
#  'ablung 200mg tablet sr',
#  'azusa 16',
#  'afoglip',
#  'acefen sp',
#  'aceclopar 100mg325mg',
#  'acotrust od 300mg tablet er',
#  'avas 40',
#  'acegaba nt 400mg10mg',
#  'alerid cold',
#  'acolate',
#  'antoxid e softgel',
#  'agoprex',
#  'amlip 25',
#  'af 300',
#  'abiways 200 sr',
#  'atorva 5',
#  'ambizyme 300mg',
#  'acegrow 3d',
#  'alerfri',
#  'aceret 25',
#  'alprax plus tablet sr',
#  'amtasm 25 tablet pr',
#  'anset 4mg tablet md',
#  'acecloren',
#  'atraxin 25',
#  'atorva gold 10',
#  'amlongtl 40',
#  'apraize 30',
#  'aspirin 300mg',
#  'akurit',
#  'agna 10000 capsule dr',
#  'atormac gold 10',
#  'altonil plus 5',
#  'acimolsp',
#  'avas cv 20',
#  'amlopres 25',
#  'aceclowal p 100mg500mg',
#  'ablung 100mg',
#  'armod 50',
#  'alcros sb 50',
#  'alkem cold 5 mg500 mg5 mg',
#  'azovas t 40',
#  'asomextm',
#  'acekay sera',
#  'alprax 1mg tablet sr',
#  'amoxiblecl 625',
#  'alzilm 10',
#  'ageless',
#  'agycin 500mg',
#  'amnurite beta 1040 er',
#  'altonil 10',
#  'atorlip gold 10',
#  'aceloflam plus',
#  'altonil plus 10',
#  'ampilox cv 500 mg125 mg',
#  'alconol 500mg',
#  'atchol cv',
#  'atormac gold 20',
#  'allegra 120mg',
#  'acepar 100mg325mg',
#  'ampanel 4',
#  'aztor ez',
#  'alfakit',
#  'atocor 20',
#  'amitryn 25',
#  'atormac cv 20',
#  'arbitelmt 25 tablet er',
#  'azi 500mg',
#  'alphadopa',
#  'abz 400mg',
#  'allerkast lc',
#  'amlodac t 40 mg5 mg',
#  'absolut dm',
#  'azikind 500mg',
#  'avoprost d 8mg05mg',
#  'arbitelav',
#  'atorlip 80',
#  'atocorcv 10',
#  'amnuring 5 tablet sr',
#  'aldactone t 10',
#  'addkay tablet pr',
#  'acotibien 100mg',
#  'alsitam 100 forte tablet er',
#  'amoxil 250mg',
#  'amicet plus',
#  'azitus 500',
#  'atorlipasp 20',
#  'allegra 30mg',
#  'acutrol c 400',
#  'ace proxyvon th 4',
#  'almefkemd',
#  'ata',
#  'amisant 200',
#  'allercetl',
#  'arbitel 20',
#  'acrotac 10mg',
#  'aginal 5',
#  'amtas 25',
#  'aricep 10',
#  'astin cv 10',
#  'amodep 5',
#  'arifine 25',
#  'azithral 250mg dt',
#  'aricepm',
#  'amoxy 250mg',
#  'alorti',
#  'atormac tg',
#  'azovas 8mg',
#  'afoglip m 1000 tablet er',
#  'anxipam 05mg tablet md',
#  'abmac',
#  'anin',
#  'apresol plus',
#  'azulix mv 2mg500mg03mg tablet sr',
#  'aceproxyvon sp',
#  'angistat 25 capsule tr',
#  'anafortan n 100 mg50 mg',
#  'atorlip cv',
#  'amoxil 250mg tablet dt',
#  'acemiz 100mg',
#  'alrista plus tablet sr',
#  'ascapil 12a tablet dt',
#  'aisa',
#  'acolate p plus',
#  'anleodsr',
#  'amlopres 10',
#  'ampoxincv 500mg125mg',
#  'azilide 250',
#  'apraize 10',
#  'atorecasp',
#  'amitrync',
#  'azee 1000',
#  'adefresh 400',
#  'abphylin 100mg',
#  'azulix mv 202 tablet sr',
#  'absolut dm',
#  'ambrodilxp',
#  'augxetil 500mg',
#  'actiheald',
#  'adilip 45 tablet dr',
#  'alfa gpc',
#  'andriol 40mg testocap',
#  'analgin 500mg',
#  'asprito 5',
#  'atrest 25',
#  'amlodac m tablet pr',
#  'atocor gold 20',
#  'atocor 80',
#  'actifed plus',
#  'alcinac p 100mg325mg',
#  'arpizol 15',
#  'arigaba nt',
#  'amlomed at 5mg50mg',
#  'azusa t 840',
#  'azomycin 500',
#  'abortab 200mg',
#  'attentrol 10mg',
#  'amace',
#  'aim7 60 xr',
#  'atchol gold 10',
#  'acenacp',
#  'aldonil plus tablet sr',
#  'acotrust',
#  'aldep 10',
#  'at sp',
#  'anxol',
#  'addwize od 18mg',
#  'amipride 50',
#  'altiva 120mg',
#  'aclonsp',
#  'allenza',
#  'atrovas 40mg',
#  'amtas 10',
#  'amlokind beta 5mg25mg tablet pr',
#  'afogatran 110',
#  'auradex 4mg',
#  'acetamide 250mg',
#  'agmacet 10mg',
#  'amloz at',
#  'arip mt 10',
#  'alivher es',
#  'ace plus',
#  'alides 5mg',
#  'alastin am',
#  'amclaid 625',
#  'avoprost 8mg',
#  'amiline 10mg',
#  'arvast f 10',
#  'amloz 5',
#  'azulix 4 mf forte tablet pr',
#  'amtasat 25',
#  'arophyll hd 10mg120mg200mg',
#  'acitrom 05',
#  'asar 40',
#  'anxit 05 sr',
#  'afoglip m 500 tablet er',
#  'arvastcf 10 capsule dr',
#  'augmentin 375 duo',
#  'axinervep tablet sr',
#  'adiflam plus 400 mg500 mg',
#  'amitop m 5mg1500mcg',
#  'asomexd',
#  'azro 500',
#  'answell 400 mg325 mg',
#  'acenext 100mg',
#  'azilup 500 mg',
#  'aceron tc',
#  'aldigesicrab capsule sr',
#  'action or 1000mg',
#  'adilin 40mg tablet sr',
#  'alfalog',
#  'azax 500',
#  'amlovasl',
#  'atorsave d 10',
#  'amit 10 mg',
#  'azivent 250',
#  'azapure',
#  'akmeentoquol',
#  'atherochek 10',
#  'axepta 18mg',
#  'alconil 500mg',
#  'actonor plus',
#  'accardi mr tablet mr',
#  'acenacsr',
#  'albutamol plus',
#  'azirin 500mg',
#  'azusa 8mg',
#  'amlodac ch',
#  'atorec 10',
#  'atrest 125',
#  'abvida 50mg',
#  'asa 75mg',
#  'amnurite 25 tablet sr',
#  'atorlip 5',
#  'amlovasm 525 tablet pr',
#  'aziford 500mg',
#  'anglit 26 tablet cr',
#  'amlogard 25mg',
#  'amdepin 5',
#  'abresp',
#  'amiodar 200',
#  'amazeo od 100 tablet sr',
#  'acocontin tablet cr',
#  'alphacept 8',
#  'augxetil cv 500',
#  'asoltat',
#  'acocare 300mg tablet sr',
#  'anti cold',
#  'advastat 10',
#  'aldigesic mr',
#  'arzu 10',
#  'asprito 10',
#  'azifast 250',
#  'alenix 5',
#  'atorbest 10',
#  'amide 25',
#  'aleva 5mg',
#  'amlopin 25',
#  'aceth 4',
#  'arip mt 15',
#  'alerfix',
#  'admol 650mg',
#  'arip 5mg',
#  'aceclomaxsp',
#  'avapar',
#  'atorsave cv 10',
#  'anaflam xps',
#  'ab day 100mg',
#  'amitril 10mg',
#  'azintas 500mg',
#  'amt 25mg',
#  'aculip 25 mg10 mg',
#  'aplev m 5mg10mg',
#  'actoid 10',
#  'aphyrenn',
#  'apigy 25',
#  'amaryl 4mg',
#  'amitop m 5',
#  'atorfit cv 40',
#  'atrovas 10mg',
#  'altoran 40',
#  'alpalide 100mg',
#  'amlogard 10mg',
#  'ambrolite 30',
#  'axepta 25mg',
#  'apraize 20',
#  'acesp',
#  'amlosafe 25',
#  'acenext sp 100 mg500 mg15 mg',
#  'amitrip 10mg',
#  'anxozap 15',
#  'atchol gold 20',
#  'acutret 5',
#  'acemyoset p',
#  'amlo at 5 mg50 mg',
#  'amirid',
#  'acendolr capsule sr',
#  'alkepin odt 125mg',
#  'amazeo 50',
#  'amucoe nac',
#  'af 50 tablet dt',
#  'abixim o',
#  'aceclodol p 100mg500mg',
#  'amlosafe h',
#  'avacardat',
#  'aldo 5mg',
#  'aztric 40',
#  'atorva e 40',
#  'atazis 10mg',
#  'amlopinm 5mg25mg',
#  'ace revelol 505 tablet er',
#  'arvast 20',
#  'aciban 40',
#  'alsitam 50 forte tablet er',
#  'amlovasat 25',
#  'alkepin odt 25mg',
#  'altam 25mg',
#  'adilan 40mg tablet sr',
#  'acepar sp 100mg325mg15mg',
#  'asomexlt',
#  'amitryn 25',
#  'arorab hd 30mg40mg capsule sr',
#  'atorsave 40',
#  'aceclomaxp',
#  'anzilum 025 mg',
#  'amodeptmh',
#  'aziwin 500',
#  'acedol p 100 mg500 mg',
#  'amchek 5',
#  'arigaba nt 100',
#  'asert d tablet er',
#  'aclopar sp 100mg325mg10mg',
#  'acecare sp',
#  'ampiloxlb',
#  'arbitelamh',
#  'amlosafe mt 25 tablet pr',
#  'arvast 5',
#  'alizap 30mg',
#  'assault novo 200 mg500 mg',
#  'avas 80',
#  'aretha',
#  'amigaba ls',
#  'astharid t',
#  'azibest 250mg',
#  'alzil 10',
#  'angicam lt 50 mg5 mg',
#  'alergin 10mg',
#  'azileb 500mg',
#  'antidep 75',
#  'alzil m forte',
#  'alergin cold total',
#  'alerfri sf 650 mg60 mg25 mg',
#  'acp tablet mr',
#  'atorva e 10mg10mg',
#  'abvidam 50mg500mg eazy glide',
#  'apexitra sb 130',
#  'aclopar 100mg500mg',
#  'ambulaxfm',
#  'alkof q',
#  'aceral capsule sr',
#  'alcecost sp 100mg325mg10mg',
#  'acera 20',
#  'amclawyn 500mg125mg',
#  'amlo 10mg',
#  'amchekat',
#  'agra 100mg',
#  'amlosafe 3d 80',
#  'aciban 20',
#  'acerest plus',
#  'acelopara',
#  'acimol 200mg tablet sr',
#  'acenext mr 100mg325mg250mg',
#  'aceloflam mr',
#  'amazeo 100',
#  'amitone forte 25 mg10 mg',
#  'apixator 25',
#  'angizem cd 120 capsule er',
#  'abvida 100mg tablet sr',
#  'auxisodaec 500',
#  'aldostix 20 mg50 mg',
#  'amlor 5mg',
#  'azrolid 500mg',
#  'alinol 10',
#  'amnurite p 10mg75mg',
#  'azulix 3 mf forte tablet pr',
#  'arkapres 100',
#  'azee 200 dt',
#  'azulix 05 mf tablet pr',
#  'amiwel 10',
#  'avas gold 75mg20mg75mg',
#  'apixator 5',
#  'acibro plus tablet sr',
#  'actinin o 20mg soft gelatin',
#  'alcinac mr',
#  'azy 500mg',
#  'aciloc d 10 mg150 mg',
#  'axinervenp',
#  'amicon 25mg',
#  'angizaarh',
#  'asthalin 2',
#  'amclox',
#  'allerzine l 5mg',
#  'alsartanh',
#  'angicamm tablet pr',
#  'atocorcv 20',
#  'abvidam 50500 eazy glide tablet sr',
#  'acipsor 25mg',
#  'avanext 200',
#  'asunra 400mg',
#  'acefile sp 100mg325mg10mg',
#  'allerblis m 20mg10mg',
#  'agmamol 500mg',
#  'averzine 10',
#  'azerva 40',
#  'atorfit cv gold 20',
#  'aps',
#  'azitro 500mg',
#  'act nvp',
#  'atrovas 20mg',
#  'apxenta 30mg',
#  'almotan 625',
#  'armod 150',
#  'atrolet 10',
#  'algest sr 200',
#  'averzine 25mg',
#  'amlosafels 55',
#  'amloz at 25',
#  'acetyl salicylic acid 50mg',
#  'astharid plus',
#  'angizaar 50',
#  'anxiset plus 05 mg10 mg',
#  'algin 100 mg500 mg',
#  'auxen d 500mg10mg',
#  'adoxy lb',
#  'aldigesic 100mg500mg250mg tablet mr',
#  'androsure 40mg',
#  'artamin 250mg',
#  'amigold 50',
#  'amazeo od 200 tablet sr',
#  'azipro 250',
#  'acecareplus',
#  'atormac 20',
#  'aspisol 150',
#  'atorsave f',
#  'arflurmr',
#  'actv 24',
#  'advastat cv 10',
#  'amigold 100',
#  'aricepm forte',
#  'apriglimmv 303 tablet sr',
#  'amtase',
#  'alphadol 05mcg soft gelatin',
#  'arreno capsule er',
#  'anafranil 25mg',
#  'apriglimmv 2 tablet sr',
#  'asomextm 5',
#  'amlosafe tm 80',
#  'alkepin odt 100mg',
#  'atorfit 20',
#  'arigaba 100',
#  'acetal mr 100mg325mg250mg',
#  'atz 50',
#  'attentrol 18',
#  'abrozac 100mg600mg',
#  'anadom 10mg500mg',
#  'asthavent 25mg respules',
#  'adova',
#  'allrite',
#  'alakast fa 10mg120mg200mg',
#  'azuvas 20gold',
#  'azitreat 500mg',
#  'azuvas 10',
#  'adineplus',
#  'adoc sp 100mg325mg',
#  'atorin 10',
#  'augulab 500mg125mg',
#  'amaryl mp 2mg tablet sr',
#  'alenix 10mg',
#  'amlace',
#  'anaflam xp 100mg325mg',
#  'azento 500mg',
#  'arifine 5mg',
#  'attera 10mg',
#  'aldactone f',
#  'aziagma 500mg',
#  'acemiz 200 sr',
#  'abmont 3d 10mg120mg200mg',
#  'altaxo 200 tablet dt',
#  'acetonp',
#  'alleronem',
#  'arflur cr',
#  'azeldip 16',
#  'alfugressd tablet sr',
#  'azimac 500mg',
#  'aldigesic spas 80mg100mg',
#  'azicip 500',
#  'anneal 60mg800mg5mg',
#  'asozen sr plus 100mg325mg10mg',
#  'amlozaar',
#  'arostat 10mg',
#  'allerduo 20mg10mg',
#  'asarct 40125',
#  'amantrel',
#  'almox dt 125',
#  'atorecf',
#  'alcinac forte 100mg325mg15mg',
#  'alkof cough lozenges orange',
#  'azuma 500mg',
#  'avort kit',
#  'azuvasf 20',
#  'apigy 5',
#  'amlovasm 2525 tablet pr',
#  'akilos tablet mr',
#  'alert 120mg',
#  'almont lc 5mg10mg',
#  'altonil plus 3',
#  'amaryl mp 2mg tablet er',
#  'abendol plus 12mg400mg',
#  'alrista forte',
#  'azulix mv 1mg500mg02mg tablet sr',
#  'alprasafe 025mg',
#  'aplex 30mg',
#  'alkepin odt 50mg',
#  'aldactone t 5',
#  'adnurve sr',
#  'alerabdsr',
#  'altacef 250mg',
#  'acepar mr',
#  'algina 650',
#  'ace',
#  'akme ct 10',
#  'alphaceptd 8',
#  'amcard 25',
#  'amox 250mg',
#  'azro 500',
#  'altrizm',
#  'apale',
#  'actiful 25mg',
#  'acefile p 100mg325mg',
#  'amlibon 5mg',
#  'afoglip',
#  'arpizol 20',
#  'acutret 30',
#  'amlovas ls',
#  'atorsave 80',
#  'arip mt 20',
#  'anafast 100mg325mg',
#  'actin',
#  'allerfree',
#  'amnurite beta 520 er',
#  'aceks',
#  'algesia p 100 mg500 mg',
#  'acenomac 2',
#  'anort 30',
#  'antrumdsr capsule capsule sr',
#  'ace p tablet 100 mg325 mg',
#  'asa 50mg',
#  'actiheal',
#  'acifix 20mg',
#  'arvast gold 10mg',
#  'atecard d',
#  'arden 500mg',
#  'acendolp',
#  'alphacept 8',
#  'amlong mt 525 tablet pr',
#  'acer plus',
#  'atocor 5',
#  'aziford 250mg',
#  'alflox 400',
#  'apexitra 200',
#  'aloja 125',
#  'avva 250mg',
#  'arthocering',
#  'arorabdsr',
#  'aceloflam xp 100 mg325 mg',
#  'angised 05mg',
#  'anaflam 400mg325mg',
#  'azithral kidtab',
#  'antegy m 20mg10mg',
#  'amisant 50',
#  'acnex 20',
#  'amlosafe 25',
#  'azuvas 40',
#  'amlokind tm 40mg5mg',
#  'argifizz 1500mg',
#  'azi 250mg',
#  ...]

# %%
np.save("db_vecs_final.npy", db_vecs)

# %%
def lower_case(df):
    df['text'] = df['text'].apply(str.lower)
    return df

def remove_punctuations(df):
    cleaned_text = []
    for index in tqdm(range(df.shape[0])):
        text = df['text'].iloc[index]

        word_tokens = text.split()
        
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in word_tokens]

        filtered_sentence = " ".join(stripped).strip()
        cleaned_text.append(filtered_sentence)
    df['text'] = np.array(cleaned_text)
    return df

def remove_null(df):
    if df['text'].isnull().sum() > 0:
        df.dropna(inplace = True)
    return df

def detect_text(path):
    """Detects text in the file."""
    
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
 
    text_list = []

    for text in texts:
        text_list.append('\n"{}"'.format(text.description))
        vertices = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]

        # vertices = (['({},{})'.format(vertex.x, vertex.y)
        #             for vertex in text.bounding_poly.vertices])
        
        #Case 1: Area using the vertices (Highest area might be the case) - WORKING
        # area = 0
        # for i in range(len(vertices)):
        #     x1, y1 = vertices[i]
        #     x2, y2 = vertices[(i + 1) % len(vertices)]
        #     area += x1 * y2 - x2 * y1
        # area /= 2
        # if area > max_area:
        #     max_area = area

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))
    
    return text_list

# %%
db_df = pd.DataFrame(db_names, columns = ['text'])
db_df
# Out:
#                            text
# 0             augmentin 625 duo
# 1                  azithral 500
# 2                 allegra 120mg
# 3                       avil 25
# 4                      allegram
# ...                         ...
# 173424  ziyapod 200mg tablet dt
# 173425       zogrell a 75mg75mg
# 173426        zef cv 200mg125mg
# 173427             zemhart 30mg
# 173428               zivex 25mg
#
# [173429 rows x 1 columns]

# %%
image_text = detect_text("Accept-SP_Tablet2 (1).jpg")
temp_df = pd.DataFrame(columns=['text'])
temp_df['text'] = image_text[0].replace("\n"," ").split()
temp_df = remove_punctuations(temp_df)
temp_df = lower_case(temp_df)
temp_df = remove_null(temp_df)
temp_df
# Out:
# 100%|██████████| 84/84 [00:00<00:00, 37592.99it/s]
#            text
# 0      acceptsp
# 1   composition
# 2          each
# 3          film
# 4        coated
# ..          ...
# 79          may
# 80           be
# 81    injurious
# 82           to
# 83        liver
#
# [84 rows x 1 columns]

# %%
# def remove_non_alphanumeric(df, columns):
#     """Remove all non-alphanumeric characters from the specified column(s) of the DataFrame."""
#     for col in columns:
#         df[col] = df[col].apply(lambda x: ''.join(e for e in x if e.isalnum()))
#     return df
def is_english(word):
    lang = process.extractOne(word, choices=['eng'], scorer=fuzz.token_sort_ratio, score_cutoff=95)
    if lang:
        return True
    else:
        return False

def is_alnum(string):
    return string.isalpha() or string.isdigit()

# %%
def filter_english(text):
    blob = TextBlob(text)
    english_words = [word for word in blob.words if TextBlob(word).detect_language() == 'en']
    return ' '.join(english_words)

# %%
# temp_df['text_without_stop'] = temp_df['text']
from nltk.corpus import stopwords
stop = stopwords.words('english')
with open('selected_words.txt', 'r') as f:
    stop_words = [word.strip().replace('"', '') for line in f.readlines() for word in line.split(',')]

stop_words.extend(['composition','tablet','capsule','capsules','tablets','warning','dosage','direction','directions','use','uses', 'physician','coated','film'])
stop.extend(stop_words)

# temp_df['text'] = temp_df['text'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in set(stop_words)]))

# new_stopwords = ['composition','tablet','capsule','capsules','tablets','warning','dosage','direction','directions','use','uses', 'physician','coated','film']
# stop.extend(new_stopwords)
temp_df['text'] = temp_df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# temp_df['text_without_stop'] = temp_df['text_without_stop'].apply(filter_english)
temp_df
# Out:
#         text
# 0   acceptsp
# 1
# 2
# 3
# 4
# ..       ...
# 79
# 80
# 81
# 82
# 83
#
# [84 rows x 1 columns]

# %%
temp_df['text'] = temp_df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
temp_df
# Out:
#               text
# 0            abpas
# 1                n
# 2              एवी
# 3              पास
# 4               एन
# ..             ...
# 68            7980
# 69           sec6a
# 70               e
# 71          sidcul
# 72  haridwar249408
#
# [73 rows x 1 columns]

# %%
def cleanDataframeEnglish(df,column_name):
  cleanedDf = pd.DataFrame(columns=['words'])
  for index, row in df.iterrows():
      word = row[column_name]
      if word.isalnum() and not word.isspace() and word.isascii():
        new_row = pd.DataFrame.from_records([{'words':word}])
        # print("New Row",new_row)
        cleanedDf = pd.concat([cleanedDf,new_row],ignore_index=True)
        # print("Iteration",cleanedDf)

  return cleanedDf

# %%
# stop_words = set(stopwords.words('english'))
# filtered_words = []

# for word in temp_df['text'].str.cat():
#     if is_english(word) and len([char for char in word if char.isalnum()]) > 0:
#         filtered_words.append(word)

# # Filter words
# clean_words = [word for word in filtered_words if word in stop_words]

# # Save cleaned words to new dataframe
# new_df = pd.DataFrame({'words': clean_words})
# print(new_df)
# Out:
# Empty DataFrame
# Columns: [words]
# Index: []

# %%
# cleanedDf = cleanDataframeEnglish(temp_df,'text')
# cleanedDf.rename(columns={0:'updated_text'}, inplace=True)
# cleanedDf
# print(temp_df)

ls = cleanDataframeEnglish(temp_df,'text')
print(ls)
# print(temp_df)
# Out:
#       words
# 0  acceptsp
# 1     20000

# %%
temp_df['text'] = remove_non_alphanumeric(temp_df, ['text'])
temp_df
# Out:
#              text
# 0            star
# 1         mankind
# 2            cimg
# 3  acebrophylline
# 4
# 5  acetylcysteine
# 6         tablets
# 7         abiways
# 8            एबवज
# 9

# %%
#Matching sequence
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
for i, row in ls.iterrows():
    # Find the most similar text in the db_name column of db_df
    max_similarity = 0
    for j, row2 in db_df.iterrows():
        # Check if the value is a float
        if isinstance(row['words'], float):
            continue
        similarity = similar(row['words'], row2['text'])
        if similarity > max_similarity:
            max_similarity = similarity
            max_row = row2
    # Print the results
    if not isinstance(row['words'], float):
        print(f"Text '{row['words']}' has the most similar text '{max_row['text']}' with a similarity score of {max_similarity}")
# Out:
# Text 'acceptsp' has the most similar text 'acceptsp' with a similarity score of 1.0
# Text '20000' has the most similar text 'gon 10000' with a similarity score of 0.5714285714285714

# %%
row = temp_df.iloc[0]
row
# Out:
# text    acceptsp
# Name: 0, dtype: object

# %%
# for index, row in temp_df.iterrows():
row = temp_df.iloc[0]
cs = cosine_similarity(nlp("acceptsp").vector.reshape(1, -1), db_vecs)
cs = cs.reshape(-1, 1)
data = {"acceptsp": cs.flatten()}
data
# Out:
# {'acceptsp': array([0.41199553, 0.3391754 , 0.16365804, ..., 0.22509345, 0.27878356,
#         0.16074592], dtype=float32)}

# %%
df = pd.DataFrame(db_names, columns=['db_names'])
df.shape
# Out:
# (173429, 1)

# %%
temp_df = pd.DataFrame(data)
df = pd.concat([df, temp_df], axis=1)
df.head()
# Out:
#             db_names  acceptsp
# 0  augmentin 625 duo  0.411996
# 1       azithral 500  0.339175
# 2      allegra 120mg  0.163658
# 3            avil 25  0.341197
# 4           allegram  0.601819

# %%
df.sort_values(by = "acceptsp", ascending=False, inplace=True)
df.head()
# Out:
#                                    db_names  acceptsp
# 84348          larazolemd kid tablet orange  0.897423
# 87366                 lebestm kid tablet md  0.865241
# 124058                         rexipra lite  0.863248
# 91277   mucimega effervescent tablet orange  0.857558
# 37956            dynagliptm forte tablet sr  0.857369

# %%
df[df['db_names'] == 'acceptsp']
# Out:
#       db_names  acceptsp
# 2238  acceptsp       1.0
